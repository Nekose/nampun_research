# %%
import numpy as np
import pandas as pd
import matplotlib
import math
from decimal import *
getcontext().prec = 64
Decimal(.001) - Decimal(.001)
# Out:
# Decimal('0E-60')

# %%
df=pd.read_excel("currentdata.xlsx")
df2=pd.read_csv("merged.csv")
#df=df.transpose()
df.head()
df2.head()
# Out:
#       type  NHLC_WT  NHLC_1A  NHLC_1B  NHLC_2A  NHLC_2B  NHLC_3A  NHLC_3B  \
# 0  p1p6del        2        0        0        0        0        0        0
# 1  p1p7del        4        0        0        0        0        0        2
# 2  p2p6del       10        0        0        0        0        0        0
# 3  p5p7del        4        0        0        0        0        0        0
# 4  p5p6del        1       90       94        0        0      212      210
#
#    NHLC_4B  NHLC_4C  ...  NHLC_17A  NHLC_17B  NHLC_18A  NHLC_18B  NHLC_19A  \
# 0        0        0  ...         0         2         2         0         0
# 1        0        0  ...         0        19         1         0         0
# 2        0        2  ...         0         0         2         0         0
# 3        0        0  ...         0         0         0         0         0
# 4       71      137  ...       339       327        11        91       105
#
#    NHLC_19B  NHLC_20A  NHLC_20B  NHLC_21A  NHLC_21B
# 0         0         0         0         3         0
# 1         0         0         3         0         2
# 2         0       418       400       175       194
# 3         0         0         0         0         0
# 4        55         0         1         3         0
#
# [5 rows x 41 columns]

# %%
for i in range(len(df["Type"])): #cleaning extra space character from type field
    value = df["Type"][i]
    df["Type"][i] = value[:-1]
df.set_index("Type", inplace=True)
# Out:
# C:\Users\nekos\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2.set_index("type", inplace=True)
df2 = df2.astype("float64")

# %%
#df["NHLC_WT"].astype(int)
ax = df.plot.bar(y="NHLC_1A", figsize = (35,5), rot=-90)
#df=df.astype(int)
#print(df.dtypes)

# %%
ax = df2.plot.bar(y="NHLC_1A", figsize = (35,5), rot=-90)

# %%
#adding one to every field for psuedocounting purposes
for key, row in df2.iteritems():
    for key2, row2 in row.iteritems():
        df2.loc[key2][key] += 1
        
for key, row in df2.iteritems():
    for key2, row2 in row.iteritems():
        if df2.loc[key2][key] <= 0:
            print("error in",key2,key)

# %%
#Convert dataframes to frequencies of each column
for key, row in df2.iteritems():
    for key2, row2 in row.iteritems():
        value = df2.loc[key2][key]
        df2.loc[key2][key] = (value / sum(row))

# %%
# calculating KL distance between two distrubtions. Distance(P||Q) = summation[Pi*Log2(Pi/Qi)]

results = {}
for key, row in df2.iteritems():
    for key2, row2 in df2.iteritems():
        if key == key2:
            continue
        data = row * np.log2(row/row2)
        resultkey = key + "-" + key2
        results[resultkey] = sum(data)

# %%
resultframe = pd.DataFrame.from_dict(results, orient = 'index', columns = ["KL_Distance"])

# %%
#Pulling values from the NHLC_16B samples:
print(resultframe[resultframe.index.str.contains("NHLC_16B-")])
# Out:
#                    KL_Distance
# NHLC_16B-NHLC_WT      8.819669
# NHLC_16B-NHLC_1A      8.401967
# NHLC_16B-NHLC_1B      8.539027
# NHLC_16B-NHLC_2A      9.001869
# NHLC_16B-NHLC_2B      9.113459
# NHLC_16B-NHLC_3A      8.721363
# NHLC_16B-NHLC_3B      7.513372
# NHLC_16B-NHLC_4B      9.135914
# NHLC_16B-NHLC_4C      8.987838
# NHLC_16B-NHLC_5A      8.321180
# NHLC_16B-NHLC_5B      8.349191
# NHLC_16B-NHLC_6A      8.576433
# NHLC_16B-NHLC_6B      7.910337
# NHLC_16B-NHLC_7A      8.725440
# NHLC_16B-NHLC_7B      8.235025
# NHLC_16B-NHLC_8A      8.476724
# NHLC_16B-NHLC_8B      9.011457
# NHLC_16B-NHLC_9A      9.070257
# NHLC_16B-NHLC_9B      8.949817
# NHLC_16B-NHLC_10A     8.714318
# NHLC_16B-NHLC_10B     8.757809
# NHLC_16B-NHLC_11A     9.147517
# NHLC_16B-NHLC_11B     9.167058
# NHLC_16B-NHLC_13A     6.647581
# NHLC_16B-NHLC_13B     9.041956
# NHLC_16B-NHLC_14A     8.927651
# NHLC_16B-NHLC_14B     8.984287
# NHLC_16B-NHLC_15D     9.014066
# NHLC_16B-NHLC_16A     5.628603
# NHLC_16B-NHLC_17A     8.798842
# NHLC_16B-NHLC_17B     8.791039
# NHLC_16B-NHLC_18A     5.677280
# NHLC_16B-NHLC_18B     8.299974
# NHLC_16B-NHLC_19A     8.651182
# NHLC_16B-NHLC_19B     8.148751
# NHLC_16B-NHLC_20A     8.481466
# NHLC_16B-NHLC_20B     8.551747
# NHLC_16B-NHLC_21A     8.699695
# NHLC_16B-NHLC_21B     8.728494

# %%
groups = {}
groupcount = {}
finalavg = {}
for key, row in resultframe.iteritems():
    for key2, row2 in row.iteritems():
        group = key2.split("-")[0]
        groups[group] = 0
        groupcount[group] = 0
    for key2, row2 in row.iteritems():
        group = key2.split("-")[0]
        groups[group] += row2
        groupcount[group] += 1

for key,value in groups.items():
    finalavg[key] = value/groupcount[key]

avgresults = pd.DataFrame.from_dict(finalavg, orient = 'index', columns = ["KL_Distance"])
display(avgresults)
ax = avgresults.plot.bar(y="KL_Distance", figsize = (20,5), rot=90)
# Out:
#           KL_Distance
# NHLC_WT      0.034250
# NHLC_1A      3.966169
# NHLC_1B      3.540064
# NHLC_2A     -0.011335
# NHLC_2B     -0.011535
# NHLC_3A      0.327135
# NHLC_3B      0.270475
# NHLC_4B      0.028801
# NHLC_4C      0.130654
# NHLC_5A      1.905422
# NHLC_5B      1.725691
# NHLC_6A      5.606348
# NHLC_6B      5.928513
# NHLC_7A      2.067047
# NHLC_7B      0.045382
# NHLC_8A      2.562012
# NHLC_8B      2.814478
# NHLC_9A     -0.011175
# NHLC_9B     -0.012060
# NHLC_10A     0.417580
# NHLC_10B     0.462543
# NHLC_11A     0.782857
# NHLC_11B     0.785176
# NHLC_13A     0.017331
# NHLC_13B    -0.008727
# NHLC_14A     0.187523
# NHLC_14B     0.142226
# NHLC_15D     4.048732
# NHLC_16A     1.408749
# NHLC_16B     8.479991
# NHLC_17A     1.877095
# NHLC_17B     1.843291
# NHLC_18A     5.697001
# NHLC_18B     3.409973
# NHLC_19A     1.148373
# NHLC_19B     3.326173
# NHLC_20A     1.504692
# NHLC_20B     1.374624
# NHLC_21A     3.426791
# NHLC_21B     3.401394

# %% [markdown]
# TO DO:
